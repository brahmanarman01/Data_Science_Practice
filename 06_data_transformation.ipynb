# %% [markdown]
# <a href="https://colab.research.google.com/github/brahmanarman01/Data_Science_Practice/blob/pandas/06_data_transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # Import the pandas library for data manipulation

# %%
df=pd.read_csv('/content/1745501008647-data_cleaning_sample.csv') # Read the CSV file into a pandas DataFrame
df # Display the DataFrame
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2=df # Create a copy of the DataFrame df and assign it to df2

# %%
df2 # Display the DataFrame df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2.bfill() # Backfill (backward fill) the missing values in df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  22.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    Alice  28.0        Delhi      F     eve@domain.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2.loc[8, 'Age']=34 # Set the 'Age' value for the row with index 8 to 34 in df2

# %%
df2 # Display the DataFrame df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie  34.0        Delhi      M    charlie@example  20-07-2021

# %%
df.sort_values("Age") # Sort the DataFrame df by the 'Age' column in ascending order
# Out:
#       Name   Age         City Gender              Email   Join Date
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 8  Charlie  34.0        Delhi      M    charlie@example  20-07-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.sort_values("Age", ascending=False) # Sort the DataFrame df by the 'Age' column in descending order
# Out:
#       Name   Age         City Gender              Email   Join Date
# 8  Charlie  34.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.reset_index(drop=True, inplace=True), # Reset the index of df, dropping the old index and modifying in place
# Out:
# (None,)

# %%
df # Display the DataFrame df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie  34.0        Delhi      M    charlie@example  20-07-2021

# %%
df2.reset_index(drop=True, inplace=True) # Reset the index of df2, dropping the old index and modifying in place

# %%
df2 # Display the DataFrame df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie  34.0        Delhi      M    charlie@example  20-07-2021

# %%
df2.ffill() # Forward fill the missing values in df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    David  28.0        Delhi      F     eve@domain.com  12-11-2019
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie  34.0        Delhi      M    charlie@example  20-07-2021

# %%
df2['rank']=df2["Age"].rank(method='dense') # Add a 'rank' column to df2 based on the 'Age' column using dense ranking

# %%
df2 # Display the DataFrame df2
# Out:
#       Name   Age         City Gender              Email   Join Date  rank
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020   4.0
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019   1.0
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN   3.0
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 8  Charlie  34.0        Delhi      M    charlie@example  20-07-2021   5.0

# %%
df2.loc[[1,3],"Age"]=[28,30] # Set the 'Age' values for rows with indices 1 and 3 to 28 and 30 respectively in df2
df2 # Display the DataFrame df2
# Out:
#       Name   Age         City Gender              Email   Join Date  rank
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 1  Charlie  28.0        Delhi      M    charlie@example  20-07-2021   NaN
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020   4.0
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021   NaN
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019   1.0
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN   3.0
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 8  Charlie  34.0        Delhi      M    charlie@example  20-07-2021   5.0

# %%
df2['rank']=df2["Age"].rank(method='dense') # Re-calculate and update the 'rank' column in df2 based on the 'Age' column using dense ranking

# %%
df2 # Display the DataFrame df2
# Out:
#       Name   Age         City Gender              Email   Join Date  rank
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 1  Charlie  28.0        Delhi      M    charlie@example  20-07-2021   3.0
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020   4.0
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021   4.0
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019   1.0
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN   3.0
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 8  Charlie  34.0        Delhi      M    charlie@example  20-07-2021   5.0

# %%
# df.rename(columns={"oldName": "newName"}, inplace=True) # Example of how to rename columns in a DataFrame
# df.rename(index={0: "row1", 1: "row2"}, inplace=True) # Example of how to rename index labels in a DataFrame

# %%
df = df[["City", "Name", "Age"]] # Select and reorder columns in DataFrame df

# %%
df # Display the DataFrame df
# Out:
#           City     Name   Age
# 0     New York    Alice  25.0
# 1        Delhi  Charlie  28.0
# 2  Los Angeles      Bob  30.0
# 3        Delhi  Charlie  30.0
# 4       Mumbai    David  22.0
# 5        Delhi      NaN  28.0
# 6     New York    Alice  25.0
# 7     New York    Alice  25.0
# 8        Delhi  Charlie  34.0

# %%
cols = ["Name"] + [col for col in df.columns if col != "Name"] # Create a list of columns with "Name" as the first element
df = df[cols] # Reorder the columns in df using the created list
df # Display the DataFrame df with reordered columns
# Out:
#       Name         City   Age
# 0    Alice     New York  25.0
# 1  Charlie        Delhi  28.0
# 2      Bob  Los Angeles  30.0
# 3  Charlie        Delhi  30.0
# 4    David       Mumbai  22.0
# 5      NaN        Delhi  28.0
# 6    Alice     New York  25.0
# 7    Alice     New York  25.0
# 8  Charlie        Delhi  34.0
