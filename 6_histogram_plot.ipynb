# %% [markdown]
# <a href="https://colab.research.google.com/github/brahmanarman01/Data_Science_Practice/blob/data-visualization-(matplotlib-and-seaborn)/6_histogram_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

ages = [
    34, 28, 36, 45, 27, 27, 45, 37, 25, 35,
    25, 25, 32, 10, 12, 24, 19, 33, 20, 15,
    44, 27, 30, 15, 24, 31, 18, 33, 23, 27,
    23, 48, 29, 19, 38, 17, 32, 10, 16, 31,
    37, 31, 28, 26, 15, 22, 25, 40, 33, 12,
    33, 26, 23, 36, 40, 39, 21, 26, 33, 39,
    25, 28, 18, 18, 38, 43, 29, 40, 33, 23,
    33, 45, 29, 45, 3, 38, 30, 27, 30, 10,
    27, 33, 44, 24, 21, 24, 39, 33, 24, 35,
    30, 39, 22, 26, 26, 15, 32, 32, 30, 27
]

bins = [10, 20, 30, 40, 50, 60, 70]

plt.hist(ages, bins=bins, edgecolor='black')
plt.title('Age Distribution of YouTube Viewers')
plt.xlabel('Age Group')
plt.ylabel('Number of Viewers')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
# Generate a histogram of the ages
plt.hist(ages, bins=bins, edgecolor='black')

# Add a vertical line at the mean age
plt.axvline(np.mean(ages), color='red', linestyle='--', linewidth=2, label='Average Age')

# Display the legend for the mean line
plt.legend()

# Set the title of the plot
plt.title('Age Distribution with Mean Line')

# Display the plot
plt.show()

# %%
# This cell is currently empty and can be used for further analysis or visualization.
